# %% [markdown]
# <a href="https://colab.research.google.com/github/JohnQUnknown/python-classes/blob/master/Ejercicios/Ejercicios_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Antes de empezar con los ejercicios, lo primero que hay que revisar es que estemos conectados a una máquina virtual en donde va a poder correr nuestro código, sin ésto es imposible que el código corra; para ésto podemos ver en la esquina superior derecha si tenemos algo como en la imagen:
#
# ![image.png](data:image/png;base64,...)
#
# De ser así habrá que darle click en *Conectar* primero para que podamos correr nuestro código y comprobar si corre como pensamos. Al final tiene que verse algo así:
# ![image.png](data:image/png;base64,...)
#
#
# Happy coding! 🍺

# %%
# Ejercicio 1
"""
Empezamos con algo bastante sencillo y es un ejemplo que ya vimos en clase.
Crea una función que acepte dos parámetros, un nombre y un año de nacimiento,
a partir de ésto la función debe de imprimir en pantalla un saludo con el nombre
escrito, calcular la edad actual y mostrarla en pantalla también junto al año actual
(usado a la hora de hacer el cálculo).
Si lo quieren hacer más elaborado se pueden hacer varias funciones para las diferentes
operaciones, pero eso se los dejo a su criterio.

Ejemplo de una funcion:

def nombre_de_la_funcion(arg1, arg2):
  print("Hola")
  return None

Ejemplo de salida:

Hola Emilio, veo que en éste año (2021) cumples 35 años, felicidades!

"""

# %%
# Ejercicio 2

"""
Continuando con cosas que ya vimos en clase, crea cuatro funciones para las operaciones
aritméticas básicas: suma, resta, multiplicación y división.
Cada función admitirá al menos dos argumentos y regresará el resultado de dicha operación
cuando sea invocado.

Ejemplo:
print(suma(3,5))
>> 8

"""
